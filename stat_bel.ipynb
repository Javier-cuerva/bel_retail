# %%
import pandas as pd

belstat_url = "https://bestat.statbel.fgov.be/bestat/api/views/579d7dca-e711-4cb4-815a-4d8a60dda1ae/result/CSV"
data = pd.read_csv(belstat_url)

# %%
data.info()
data.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1170 entries, 0 to 1169
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   NACE groups                  1170 non-null   object
#  1   Reference month              1170 non-null   object
#  2   Gross index                  1170 non-null   float64
#  3   Trend of the index           1170 non-null   float64
#  4   Deflated gross index         1170 non-null   float64
#  5   Deflated index (SA-WDA)      1170 non-null   float64
#  6   Trend of the deflated index  1170 non-null   float64
#  7   Deflated index (WDA)         1170 non-null   float64
#  8   Index (SA-WDA)               1170 non-null   float64
#  9   Index (WDA)                  1170 non-null   float64
# dtypes: float64(8), object(2)
# memory usage: 91.5+ KB
# Index(['NACE groups', 'Reference month', 'Gross index', 'Trend of the index',
# ...

# %%
data["Reference month"].unique()
# Out:
# array(['January 2013', 'February 2013', 'March 2013', 'April 2013',
#        'May 2013', 'June 2013', 'July 2013', 'August 2013',
#        'September 2013', 'October 2013', 'November 2013', 'December 2013',
#        'January 2014', 'February 2014', 'March 2014', 'April 2014',
#        'May 2014', 'June 2014', 'July 2014', 'August 2014',
#        'September 2014', 'October 2014', 'November 2014', 'December 2014',
#        'January 2015', 'February 2015', 'March 2015', 'April 2015',
#        'May 2015', 'June 2015', 'July 2015', 'August 2015',
#        'September 2015', 'October 2015', 'November 2015', 'December 2015',
#        'January 2016', 'February 2016', 'March 2016', 'April 2016',
#        'May 2016', 'June 2016', 'July 2016', 'August 2016',
#        'September 2016', 'October 2016', 'November 2016', 'December 2016',
#        'January 2017', 'February 2017', 'March 2017', 'April 2017',
#        'May 2017', 'June 2017', 'July 2017', 'August 2017',
# ...

# %%
data["Year"] = data.apply(lambda row: int(row["Reference month"][-4:]), axis="columns")
data["Month Name"] = data.apply(lambda row: row["Reference month"][:-5], axis="columns")
data.head()
# Out:
#                                          NACE groups Reference month  \
# 0  Retail trade, except of motor vehicles, motorc...    January 2013
# 1  Retail trade, except of motor vehicles, motorc...   February 2013
# 2  Retail trade, except of motor vehicles, motorc...      March 2013
# 3  Retail trade, except of motor vehicles, motorc...      April 2013
# 4  Retail trade, except of motor vehicles, motorc...        May 2013
#
#    Gross index  Trend of the index  Deflated gross index  \
# 0       97.728              96.517                97.521
# 1       84.018              96.578                83.532
# 2       97.348              96.620                96.857
# 3       93.769              96.681                92.975
# 4       97.528              96.789                96.292
#
#    Deflated index (SA-WDA)  Trend of the deflated index  Deflated index (WDA)  \
# 0                   97.799                       96.347                97.523
# ...

# %%
import calendar

month_map = pd.DataFrame(
    data={
        "Month Name": list(calendar.month_name)[1:],
        "Month Number": list(range(1, 13))
    }
)

data = pd.merge(data, month_map, on="Month Name")
data.head()
# Out:
#                                          NACE groups Reference month  \
# 0  Retail trade, except of motor vehicles, motorc...    January 2013
# 1  Retail trade, except of motor vehicles, motorc...    January 2014
# 2  Retail trade, except of motor vehicles, motorc...    January 2015
# 3  Retail trade, except of motor vehicles, motorc...    January 2016
# 4  Retail trade, except of motor vehicles, motorc...    January 2017
#
#    Gross index  Trend of the index  Deflated gross index  \
# 0       97.728              96.517                97.521
# 1       99.090              97.662                98.042
# 2      100.844              99.009               101.830
# 3       98.367              99.813                98.295
# 4      100.935             101.517                99.422
#
#    Deflated index (SA-WDA)  Trend of the deflated index  Deflated index (WDA)  \
# 0                   97.799                       96.347                97.523
# ...
